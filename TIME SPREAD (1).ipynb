# %% [markdown]
# # **TTF TIME SPREAD**

# %%
import sys
sys.path.append(r"C:\Users\Elie\Elie code\Function\TTF")
import warnings
warnings.filterwarnings('ignore')
# import des fonctions
from Spread import SpreadAnalyzer
from Data_cleaning import load_commodity_data_final
from scipy import stats

# %%
analyzer = SpreadAnalyzer()

# %%
analyzer.composite_variation(markets='TTF')
# Out:
# 🎯 36 daily contracts successfully loaded
#
#
# ====================================================================================================
#                                           DAILY VARIATIONS
# ====================================================================================================
# Contract     Market   Price (€/MWh) Var. €   Var. %   Status     Date         Cov.
# ----------------------------------------------------------------------------------------------------
# Q425         TTF        33.109      -        -        EXPIRED    29/09        3/3
# Winter25     TTF        33.325      -        -        EXPIRED    29/09        6/6
# Cal26        TTF        30.974       -0.020 🟣  -0.06% ACTIVE     14/10→15/10  12/12
# Q126         TTF        32.094       -0.031 🟣  -0.10% ACTIVE     14/10→15/10  3/3
# Q226         TTF        30.298       -0.006 🟣  -0.02% ACTIVE     14/10→15/10  3/3
# Q326         TTF        30.292       -0.004 🟣  -0.01% ACTIVE     14/10→15/10  3/3
# Q426         TTF        31.210       -0.039 🟣  -0.12% ACTIVE     14/10→15/10  3/3
# Summer26     TTF        30.295       -0.005 🟣  -0.02% ACTIVE     14/10→15/10  6/6
# Winter26     TTF        31.363       -0.036 🟣  -0.12% ACTIVE     14/10→15/10  6/6
#
# 🎨 Color legend:
# 🟢 Strong increase (≥5%)  🟡 Moderate increase (2-5%)  🟠 Low increase (<2%)
# 🔴 Strong decline (≥5%)  🟤 Moderate decline (2-5%)  🟣 Low decline (<2%)
# 📌 EXPIRED : Price fixed on the expiration date
# 📌 ACTIVE  : Calculated variations over the period
#
# ====================================================================================================
#                                          WEEKLY VARIATIONS
# ====================================================================================================
# Contract     Market   Price (€/MWh) Var. €   Var. %   Status     Date         Cov.
# ----------------------------------------------------------------------------------------------------
# Q425         TTF        33.109      -        -        EXPIRED    29/09        3/3
# Winter25     TTF        33.325      -        -        EXPIRED    29/09        6/6
# Cal26        TTF        30.974       -0.877 🟤  -2.75% ACTIVE     08/10→15/10  12/12
# Q126         TTF        32.094       -0.924 🟤  -2.80% ACTIVE     08/10→15/10  3/3
# Q226         TTF        30.298       -0.844 🟤  -2.71% ACTIVE     08/10→15/10  3/3
# Q326         TTF        30.292       -0.841 🟤  -2.70% ACTIVE     08/10→15/10  3/3
# Q426         TTF        31.210       -0.901 🟤  -2.81% ACTIVE     08/10→15/10  3/3
# Summer26     TTF        30.295       -0.842 🟤  -2.70% ACTIVE     08/10→15/10  6/6
# Winter26     TTF        31.363       -0.893 🟤  -2.77% ACTIVE     08/10→15/10  6/6
#
# 🎨 Color legend:
# 🟢 Strong increase (≥5%)  🟡 Moderate increase (2-5%)  🟠 Low increase (<2%)
# 🔴 Strong decline (≥5%)  🟤 Moderate decline (2-5%)  🟣 Low decline (<2%)
# 📌 EXPIRED : Price fixed on the expiration date
# 📌 ACTIVE  : Calculated variations over the period
#
# ====================================================================================================
#                                          MONTHLY VARIATIONS
# ====================================================================================================
# Contract     Market   Price (€/MWh) Var. €   Var. %   Status     Date         Cov.
# ----------------------------------------------------------------------------------------------------
# Q425         TTF        33.109      -        -        EXPIRED    29/09        3/3
# Winter25     TTF        33.325      -        -        EXPIRED    29/09        6/6
# Cal26        TTF        30.974       -1.100 🟤  -3.43% ACTIVE     15/09→15/10  12/12
# Q126         TTF        32.094       -1.350 🟤  -4.04% ACTIVE     15/09→15/10  3/3
# Q226         TTF        30.298       -1.068 🟤  -3.40% ACTIVE     15/09→15/10  3/3
# Q326         TTF        30.292       -1.011 🟤  -3.23% ACTIVE     15/09→15/10  3/3
# Q426         TTF        31.210       -0.972 🟤  -3.02% ACTIVE     15/09→15/10  3/3
# Summer26     TTF        30.295       -1.039 🟤  -3.32% ACTIVE     15/09→15/10  6/6
# Winter26     TTF        31.363       -0.969 🟤  -3.00% ACTIVE     15/09→15/10  6/6
#
# 🎨 Color legend:
# 🟢 Strong increase (≥5%)  🟡 Moderate increase (2-5%)  🟠 Low increase (<2%)
# 🔴 Strong decline (≥5%)  🟤 Moderate decline (2-5%)  🟣 Low decline (<2%)
# 📌 EXPIRED : Price fixed on the expiration date
# 📌 ACTIVE  : Calculated variations over the period

# %%
analyzer.time_spread(market='TTF', type='composite', 
                    contracts='Winter26 vs Summer26', volatility_window=20)
# Out:
# 📅 TIME SPREAD ANALYSIS - TTF
# ================================================================================
#
# 📊 Contract pair: Winter26 vs Summer26
# --------------------------------------------------
# ✅ Composite price Winter26: 31.363 €/MWh (6/6 contracts)
# ✅ Composite price Summer26: 30.295 €/MWh (6/6 contracts)
# 💰 Current time spread: +1.068 €/MWh
#    └─ TTF Winter26: 31.363 €/MWh
#    └─ TTF Summer26: 30.295 €/MWh
# 📅 Date: 15/10/2025
#
# 📊 Spread variations:
#    • Day     : +0.000 €/MWh ⚪ +0.0% (since 15/10)
#    • Week    : -0.051 €/MWh 🟤 -4.5% (since 08/10)
#    • Month   : +0.047 €/MWh 🟡 +4.6% (since 17/09)
# 📊 TIME SPREAD VOLATILITY & RETURNS ANALYSIS - Winter26 vs Summer26 (Volatility window: 20 days)
# ==========================================================================================
# 📅 Analysis period: 202/202 valid days
# 📊 Total volatility (without outliers): 15.2026%
# 📊 Spread min/max: -2.932 / +1.230 €/MWh
