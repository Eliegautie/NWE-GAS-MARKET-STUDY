# %% [markdown]
# # **TTF TIME SPREAD**

# %%
import sys
sys.path.append(r"C:\Users\Elie\Elie code\Function\TTF")
import warnings
warnings.filterwarnings('ignore')
# import des fonctions
from Spread import SpreadAnalyzer
from Data_cleaning import load_commodity_data_final
from scipy import stats

# %%
analyzer = SpreadAnalyzer()

# %%
analyzer.composite_variation(markets='TTF')
# Out:
# 🎯 36 daily contracts successfully loaded
#
#
# ...
#                                           DAILY VARIATIONS
# ...
# Contract     Market   Price (€/MWh) Var. €   Var. %   Status     Date         Cov.
# ----------------------------------------------------------------------------------------------------
# Q425         TTF        33.109      -        -        EXPIRED    29/09        3/3
# Winter25     TTF        33.325      -        -        EXPIRED    29/09        6/6
# Cal26        TTF        30.694       -0.103 🟣  -0.34% ACTIVE     17/10→20/10  12/12
# Q126         TTF        31.897       -0.079 🟣  -0.25% ACTIVE     17/10→20/10  3/3
# Q226         TTF        29.979       -0.121 🟣  -0.40% ACTIVE     17/10→20/10  3/3
# Q326         TTF        29.988       -0.115 🟣  -0.38% ACTIVE     17/10→20/10  3/3
# Q426         TTF        30.914       -0.099 🟣  -0.32% ACTIVE     17/10→20/10  3/3
# Summer26     TTF        29.983       -0.118 🟣  -0.39% ACTIVE     17/10→20/10  6/6
# ...

# %%
analyzer.time_spread(market='TTF', type='composite', 
                    contracts='Winter26 vs Summer26', volatility_window=20)
# Out:
# 📅 TIME SPREAD ANALYSIS - TTF
# ...
#
# 📊 Contract pair: Winter26 vs Summer26
# --------------------------------------------------
# ✅ Composite price Winter26: 31.062 €/MWh (6/6 contracts)
# ✅ Composite price Summer26: 29.983 €/MWh (6/6 contracts)
# 💰 Current time spread: +1.079 €/MWh
#    └─ TTF Winter26: 31.062 €/MWh
#    └─ TTF Summer26: 29.983 €/MWh
# 📅 Date: 20/10/2025
#
# 📊 Spread variations:
#    • Day     : +0.027 €/MWh 🟡 +2.5% (since 17/10)
#    • Week    : -0.059 €/MWh 🔴 -5.2% (since 13/10)
#    • Month   : -0.034 €/MWh 🟤 -3.1% (since 22/09)
# 📊 TIME SPREAD VOLATILITY & RETURNS ANALYSIS - Winter26 vs Summer26 (Volatility window: 20 days)
# ...
# 📅 Analysis period: 205/205 valid days
# 📊 Total volatility (without outliers): 15.0795%
# 📊 Spread min/max: -2.932 / +1.230 €/MWh
